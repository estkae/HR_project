# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
from statsmodels.formula.api import ols
import itertools
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder, LabelBinarizer, binarize
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

# SMOTE
import imblearn
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from matplotlib import pyplot
from numpy import where
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from matplotlib import pyplot

#KNN Imports
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

#decision trees Imports
from sklearn.tree import DecisionTreeRegressor
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
# import pydotplus
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold
from sklearn.externals.six import StringIO

#Random Forest Imports
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
# pip install statsmodels

# %%
hr_data = pd.read_csv('datafiles/hrdata_cleaned',index_col=0)

# %%
df_target = hr_data['performance_score_Exceptional']+hr_data['performance_score_Exceeds']
df_feats = hr_data.drop(columns=['performance_score_Exceeds','performance_score_Exceptional','performance_score_Fully Meets','performance_score_N/A- too early to review','performance_score_Needs Improvement','performance_score_PIP'])

# %% [markdown]
# # Train Test Split

# %%
#creating matrix of features 
X = df_feats.drop(columns=['name'])
#assigning target variable 
y = df_target
#creating a list of features
feature_cols = X.columns

# %%
y.value_counts()
# Out:
# 0    263
# 1     37
# dtype: int64

# %%
# Use x and y variables to split the training data into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .40,random_state=42)

# %% [markdown]
# 1. Logistic Regression

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
dictionary = dict(zip(list(X_train.columns), list(logreg.coef_[0])))
# make class predictions for the testing set
y_pred_class = logreg.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, y_pred_class))
# Out:
# 0.8583333333333333

# %%
y_test.value_counts()
# Out:
# 0    107
# 1     13
# dtype: int64

# %%
# IMPORTANT: first argument is true values, second argument is predicted values
print(metrics.confusion_matrix(y_test, y_pred_class))
# Out:
# [[102   5]
#  [ 12   1]]

# %%
#pip install imbalanced-learn

# %%
# transform the dataset
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 263, 1: 263})

# %%
# Use x and y variables to split the training data into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .40,random_state=42)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
dictionary = dict(zip(list(X_train.columns), list(logreg.coef_[0])))
# make class predictions for the testing set
y_pred_class = logreg.predict(X_test)
print('Accuracy_Score--------')
print(metrics.accuracy_score(y_test, y_pred_class))
print('\n')
print('Value_Counts--------')
print(y_test.value_counts())
# Out:
# Accuracy_Score--------
# 0.8625592417061612
#
#
# Value_Counts--------
# 1    111
# 0    100
# dtype: int64

# %% [markdown]
# **Confusion matrix**

# %%
print(metrics.confusion_matrix(y_test, y_pred_class))
# Out:
# [[89 11]
#  [18 93]]

# %% [markdown]
# # 1. Is there any relationship between who a person works for and their performance score?
# - Correlation between manager and performance score

# %%
hr_data = hr_data.set_index('name')

# %%
data = pd.read_csv('datafiles/HR_dataset.csv')

# %%
data = data.set_index('Employee Name')
data = pd.get_dummies(data, columns = ['Performance Score'])
data
# Out:
#                       Employee Number State     Zip       DOB   Age     Sex  \
# Employee Name
# Brown, Mia               1.103024e+09    MA  1450.0  11/24/85  32.0  Female
# LaRotonda, William       1.106027e+09    MA  1460.0   4/26/84  33.0    Male
# Steans, Tyrone           1.302053e+09    MA  2703.0    9/1/86  31.0    Male
# Howard, Estelle          1.211051e+09    MA  2170.0   9/16/85  32.0  Female
# Singh, Nan               1.307060e+09    MA  2330.0   5/19/88  29.0  Female
# ...                               ...   ...     ...       ...   ...     ...
# Saada, Adell             1.012023e+09    MA  2132.0   7/24/86  31.0  Female
# Szabo, Andrew            1.201031e+09    MA  2140.0    5/6/83  34.0    Male
# True, Edward             1.102024e+09    MA  2451.0   6/14/83  34.0    Male
# Sweetwater, Alex         1.001645e+09    MA  2184.0  11/22/66  51.0    Male
# NaN                               NaN   NaN     NaN       NaN   NaN     NaN
#
#                      MaritalDesc  CitizenDesc Hispanic/Latino  \
# Employee Name
# Brown, Mia               Married   US Citizen              No
# LaRotonda, William      Divorced   US Citizen              No
# Steans, Tyrone            Single   US Citizen              No
# Howard, Estelle          Married   US Citizen              No
# Singh, Nan                Single   US Citizen              No
# ...                          ...          ...             ...
# Saada, Adell             Married   US Citizen              No
# Szabo, Andrew             Single   US Citizen              No
# True, Edward              Single  Non-Citizen              No
# Sweetwater, Alex          Single   US Citizen              No
# NaN                          NaN          NaN             NaN
#
#                                        RaceDesc  ... Pay Rate  \
# Employee Name                                    ...
# Brown, Mia            Black or African American  ...    28.50
# LaRotonda, William    Black or African American  ...    23.00
# Steans, Tyrone                            White  ...    29.00
# Howard, Estelle                           White  ...    21.50
# Singh, Nan                                White  ...    16.56
# ...                                         ...  ...      ...
# Saada, Adell                              White  ...    49.25
# Szabo, Andrew                             White  ...    48.00
# True, Edward          Black or African American  ...    45.42
# Sweetwater, Alex                          White  ...    27.00
# NaN                                         NaN  ...      NaN
#
#                             Manager Name                    Employee Source  \
# Employee Name
# Brown, Mia            Brandon R. LeBlanc                 Diversity Job Fair
# LaRotonda, William    Brandon R. LeBlanc                 Website Banner Ads
# Steans, Tyrone        Brandon R. LeBlanc                    Internet Search
# Howard, Estelle       Brandon R. LeBlanc             Pay Per Click - Google
# Singh, Nan            Brandon R. LeBlanc                 Website Banner Ads
# ...                                  ...                                ...
# Saada, Adell             Alex Sweetwater             Pay Per Click - Google
# Szabo, Andrew            Alex Sweetwater                           MBTA ads
# True, Edward             Alex Sweetwater                 Diversity Job Fair
# Sweetwater, Alex         Jennifer Zamora  Search Engine - Google Bing Yahoo
# NaN                                  NaN                                NaN
#
#                      Performance Score_90-day meets Performance Score_Exceeds  \
# Employee Name
# Brown, Mia                                        0                         0
# LaRotonda, William                                0                         0
# Steans, Tyrone                                    0                         0
# Howard, Estelle                                   0                         0
# Singh, Nan                                        0                         0
# ...                                             ...                       ...
# Saada, Adell                                      0                         0
# Szabo, Andrew                                     0                         0
# True, Edward                                      0                         0
# Sweetwater, Alex                                  0                         0
# NaN                                               0                         0
#
#                      Performance Score_Exceptional  \
# Employee Name
# Brown, Mia                                       0
# LaRotonda, William                               0
# Steans, Tyrone                                   0
# Howard, Estelle                                  0
# Singh, Nan                                       0
# ...                                            ...
# Saada, Adell                                     0
# Szabo, Andrew                                    1
# True, Edward                                     0
# Sweetwater, Alex                                 0
# NaN                                              0
#
#                       Performance Score_Fully Meets  \
# Employee Name
# Brown, Mia                                        1
# LaRotonda, William                                1
# Steans, Tyrone                                    1
# Howard, Estelle                                   0
# Singh, Nan                                        0
# ...                                             ...
# Saada, Adell                                      1
# Szabo, Andrew                                     0
# True, Edward                                      1
# Sweetwater, Alex                                  1
# NaN                                               0
#
#                      Performance Score_N/A- too early to review  \
# Employee Name
# Brown, Mia                                                    0
# LaRotonda, William                                            0
# Steans, Tyrone                                                0
# Howard, Estelle                                               1
# Singh, Nan                                                    1
# ...                                                         ...
# Saada, Adell                                                  0
# Szabo, Andrew                                                 0
# True, Edward                                                  0
# Sweetwater, Alex                                              0
# NaN                                                           0
#
#                      Performance Score_Needs Improvement  \
# Employee Name
# Brown, Mia                                             0
# LaRotonda, William                                     0
# Steans, Tyrone                                         0
# Howard, Estelle                                        0
# Singh, Nan                                             0
# ...                                                  ...
# Saada, Adell                                           0
# Szabo, Andrew                                          0
# True, Edward                                           0
# Sweetwater, Alex                                       0
# NaN                                                    0
#
#                       Performance Score_PIP
# Employee Name
# Brown, Mia                                0
# LaRotonda, William                        0
# Steans, Tyrone                            0
# Howard, Estelle                           0
# Singh, Nan                                0
# ...                                     ...
# Saada, Adell                              0
# Szabo, Andrew                             0
# True, Edward                              0
# Sweetwater, Alex                          0
# NaN                                       0
#
# [302 rows x 26 columns]

# %%
list(data.columns)
# Out:
# ['Employee Number',
#  'State',
#  'Zip',
#  'DOB',
#  'Age',
#  'Sex',
#  'MaritalDesc',
#  'CitizenDesc',
#  'Hispanic/Latino',
#  'RaceDesc',
#  'Date of Hire',
#  'Date of Termination',
#  'Reason For Term',
#  'Employment Status',
#  'Department',
#  'Position',
#  'Pay Rate',
#  'Manager Name',
#  'Employee Source',
#  'Performance Score_90-day meets',
#  'Performance Score_Exceeds',
#  'Performance Score_Exceptional',
#  'Performance Score_Fully Meets',
#  'Performance Score_N/A- too early to review',
#  'Performance Score_Needs Improvement',
#  'Performance Score_PIP']

# %% [markdown]
# # Heatmap

# %%
full_df = pd.read_csv('datafiles/HR_dataset.csv', index_col=0)
perf_score = pd.DataFrame(full_df['Performance Score'])
manager_list = pd.DataFrame(full_df['Manager Name'])
manager_performances = pd.concat([perf_score,manager_list], axis=1)

# %%
manager_performances.columns=['performance','manager']

# %%
manager_performances['manager'].value_counts()
# Out:
# Kissy Sullivan        22
# Kelley Spirea         22
# Michael Albert        22
# Elijiah Gray          22
# Amy Dunn              21
# Webster Butler        21
# Brannon Miller        21
# David Stanley         21
# Ketsia Liebig         21
# Janet King            19
# Simon Roup            17
# Peter Monroe          14
# John Smith            14
# Lynn Daneault         13
# Alex Sweetwater        9
# Brandon R. LeBlanc     7
# Jennifer Zamora        6
# Eric Dougall           4
# Debra Houlihan         3
# Board of Directors     2
# Name: manager, dtype: int64

# %%
df1 = pd.get_dummies(manager_performances, columns = ['manager'], drop_first=True )
#Alex Sweetwater was dropped

# %%
# df1 = df1.groupby('performance')

# %%
df1_corr = df1.corr()
df1_corr = df1_corr.fillna(0)

# %%
df1['performance'].unique()
# Out:
# array(['Fully Meets', 'N/A- too early to review', '90-day meets',
#        'Exceptional', 'Needs Improvement', 'Exceeds', 'PIP', nan],
#       dtype=object)

# %%
df1['performance'] = df1['performance'].replace(['Fully Meets',
                                                 'N/A- too early to review',
                                                 '90-day meets','Exceptional', 
                                                 'Needs Improvement',
                                                 'Exceeds', 
                                                 'PIP'],
                                                ['fully_meets','too_early',
                                                'ninety_day', 'exceptional',
                                                'needs_improvement',
                                                 'exceeds',
                                                'pip'])
# df1['performance'] = df1['performance'].replace('Fully Meets','fully_meets')

# %%
df1
# Out:
#                       performance  manager_Amy Dunn  \
# Employee Name
# Brown, Mia            fully_meets                 0
# LaRotonda, William    fully_meets                 0
# Steans, Tyrone        fully_meets                 0
# Howard, Estelle         too_early                 0
# Singh, Nan              too_early                 0
# ...                           ...               ...
# Saada, Adell          fully_meets                 0
# Szabo, Andrew         exceptional                 0
# True, Edward          fully_meets                 0
# Sweetwater, Alex      fully_meets                 0
# NaN                           NaN                 0
#
#                       manager_Board of Directors  manager_Brandon R. LeBlanc  \
# Employee Name
# Brown, Mia                                     0                           1
# LaRotonda, William                             0                           1
# Steans, Tyrone                                 0                           1
# Howard, Estelle                                0                           1
# Singh, Nan                                     0                           1
# ...                                          ...                         ...
# Saada, Adell                                   0                           0
# Szabo, Andrew                                  0                           0
# True, Edward                                   0                           0
# Sweetwater, Alex                               0                           0
# NaN                                            0                           0
#
#                       manager_Brannon Miller  manager_David Stanley  \
# Employee Name
# Brown, Mia                                 0                      0
# LaRotonda, William                         0                      0
# Steans, Tyrone                             0                      0
# Howard, Estelle                            0                      0
# Singh, Nan                                 0                      0
# ...                                      ...                    ...
# Saada, Adell                               0                      0
# Szabo, Andrew                              0                      0
# True, Edward                               0                      0
# Sweetwater, Alex                           0                      0
# NaN                                        0                      0
#
#                       manager_Debra Houlihan  manager_Elijiah Gray  \
# Employee Name
# Brown, Mia                                 0                     0
# LaRotonda, William                         0                     0
# Steans, Tyrone                             0                     0
# Howard, Estelle                            0                     0
# Singh, Nan                                 0                     0
# ...                                      ...                   ...
# Saada, Adell                               0                     0
# Szabo, Andrew                              0                     0
# True, Edward                               0                     0
# Sweetwater, Alex                           0                     0
# NaN                                        0                     0
#
#                       manager_Eric Dougall  manager_Janet King  \
# Employee Name
# Brown, Mia                               0                   0
# LaRotonda, William                       0                   0
# Steans, Tyrone                           0                   0
# Howard, Estelle                          0                   0
# Singh, Nan                               0                   0
# ...                                    ...                 ...
# Saada, Adell                             0                   0
# Szabo, Andrew                            0                   0
# True, Edward                             0                   0
# Sweetwater, Alex                         0                   0
# NaN                                      0                   0
#
#                       manager_Jennifer Zamora  manager_John Smith  \
# Employee Name
# Brown, Mia                                  0                   0
# LaRotonda, William                          0                   0
# Steans, Tyrone                              0                   0
# Howard, Estelle                             0                   0
# Singh, Nan                                  0                   0
# ...                                       ...                 ...
# Saada, Adell                                0                   0
# Szabo, Andrew                               0                   0
# True, Edward                                0                   0
# Sweetwater, Alex                            1                   0
# NaN                                         0                   0
#
#                       manager_Kelley Spirea  manager_Ketsia Liebig  \
# Employee Name
# Brown, Mia                                0                      0
# LaRotonda, William                        0                      0
# Steans, Tyrone                            0                      0
# Howard, Estelle                           0                      0
# Singh, Nan                                0                      0
# ...                                     ...                    ...
# Saada, Adell                              0                      0
# Szabo, Andrew                             0                      0
# True, Edward                              0                      0
# Sweetwater, Alex                          0                      0
# NaN                                       0                      0
#
#                       manager_Kissy Sullivan  manager_Lynn Daneault  \
# Employee Name
# Brown, Mia                                 0                      0
# LaRotonda, William                         0                      0
# Steans, Tyrone                             0                      0
# Howard, Estelle                            0                      0
# Singh, Nan                                 0                      0
# ...                                      ...                    ...
# Saada, Adell                               0                      0
# Szabo, Andrew                              0                      0
# True, Edward                               0                      0
# Sweetwater, Alex                           0                      0
# NaN                                        0                      0
#
#                       manager_Michael Albert  manager_Peter Monroe  \
# Employee Name
# Brown, Mia                                 0                     0
# LaRotonda, William                         0                     0
# Steans, Tyrone                             0                     0
# Howard, Estelle                            0                     0
# Singh, Nan                                 0                     0
# ...                                      ...                   ...
# Saada, Adell                               0                     0
# Szabo, Andrew                              0                     0
# True, Edward                               0                     0
# Sweetwater, Alex                           0                     0
# NaN                                        0                     0
#
#                       manager_Simon Roup  manager_Webster Butler
# Employee Name
# Brown, Mia                             0                       0
# LaRotonda, William                     0                       0
# Steans, Tyrone                         0                       0
# Howard, Estelle                        0                       0
# Singh, Nan                             0                       0
# ...                                  ...                     ...
# Saada, Adell                           0                       0
# Szabo, Andrew                          0                       0
# True, Edward                           0                       0
# Sweetwater, Alex                       0                       0
# NaN                                    0                       0
#
# [302 rows x 20 columns]

# %%
df1 = pd.get_dummies(df1, columns = ['performance'], drop_first=True )
#exceeds was dropped

# %%
df_corr = df1.corr()

# %%
sns.heatmap(df_corr)

# %% [markdown]
# **Variance** - measure of dispersion of continuous random variables from its expected mean value
#
# **Covariance** - when trying to figure out how two random variables vary together
# - A **positive** covariance indicates that two variables are positively related
# - A **negative** covariance indicates that two variables are inversely related
# - A covariance **equal or close to 0** indicates that there is no linear relationship between two variables
#
# **Correlation** is calculated by standardizing covariance by some measure of variability in the data, it produces a quantity that has intuitive interpretations and consistent scale.
# - **Pearson Correlation Coefficient**,  𝑟 , also called the linear correlation coefficient, measures the strength and the direction of a linear relationship between two variables. This coefficient quantifies the degree to which a relationship between two variables can be described by a line.

# %% [markdown]
# **1. Mean normalized**

# %%
# Write a function to take in an iterable, calculate the mean and subtract the mean value
# from each element, creating and returning a new list. 
def mean_normalize(var):
    norm = [] # Vector for storing output values 
    mean = sum(var)/len(var)   
    for i in var: # for each element in the vector, subtract from mean and add the result to norm
        diff = i - mean
        norm.append(diff)
    return norm

# %%
age_normalized = mean_normalize(hr_data['age'])
# Visualize the age data distribution before and after mean normalization 
sns.distplot(age_normalized)
sns.distplot(hr_data['age'])
plt.title('Age Normalized')
# Out:
# Text(0.5, 1.0, 'Age Normalized')

# %% [markdown]
# - Notice the shape of the data isn't changed, but the mean is just shifted (normalization process)

# %%
pay_normalized = mean_normalize(hr_data['pay_rate'])
# Visualize the PAY data distribution before and after mean normalization 
sns.distplot(pay_normalized)
sns.distplot(hr_data['pay_rate'])
plt.title('Pay Rate Normalized')
# Out:
# Text(0.5, 1.0, 'Pay Rate Normalized')

# %%
# FUNCTION: dot product of two iterables 
def dot_product(x, y):
    prod_vec = 0 # Initliaze an empty list to store the results 
    # For all elements in the vectors, multiply and save results in prod_vec
    for i in range(len(x)):
        prod = x[i]* y[i]
        prod_vec += prod
    return prod_vec

# %%
def covariance(var1, var2):
    # Formula for covariance is:
    # [Sum (x_i - X)(y_i - Y)] / N-1 
    # Sanity Check: Check to see if both vectors are of same length
    # Exit the function if variables have different lengths
    if len(var1) != len(var2):
        return 'The lengths of both the lists should be equal.' 
    else: 
        # Mean normalize both variables 
        x = mean_normalize(var1)
        y = mean_normalize(var2)
        # Take the dot product of mean normalized variables
        result = dot_product(x, y)
        # divide the dot product by n-1    
        return result /((len(var1)) - 1)

# %%
covariance(age_normalized,pay_normalized)
# Out:
# 2.448728205128202

# %%
plt.scatter(age_normalized,pay_normalized)

# %% [markdown]
# - you can see that there is no relationship between age and pay

# %%
# Calculate Correlation between two variables using formula above
import math
def correlation(var1, var2):  
    if len(var1) != len(var2):
        return 'The lengths of both the lists should be equal.' 
    else: 
       
        mean_norm_var1 = mean_normalize(var1)
        mean_norm_var2 = mean_normalize(var2)
        var1_dot_var2 = dot_product(mean_norm_var1, mean_norm_var2)
        var1_squared = [i * i for i in mean_norm_var1]
        var2_squared = [i * i for i in mean_norm_var2]
        return round(var1_dot_var2 / math.sqrt(sum(var1_squared) * sum(var2_squared)), 2)

correlation(age_normalized,pay_normalized)
# Out:
# 0.02

# %%
# Check - LOW CORRELATION BETWEEN AGE AND PAY

pay = hr_data['pay_rate']
age = hr_data['age']
pay_age = pd.concat([pay,age], axis = 1)
pay_age.corr()
# Out:
#           pay_rate       age
# pay_rate  1.000000  0.017995
# age       0.017995  1.000000

# %%
df1 = pd.read_csv('datafiles/HR_dataset.csv')
df1.keys()
# Out:
# Index(['Employee Name', 'Employee Number', 'State', 'Zip', 'DOB', 'Age', 'Sex',
#        'MaritalDesc', 'CitizenDesc', 'Hispanic/Latino', 'RaceDesc',
#        'Date of Hire', 'Date of Termination', 'Reason For Term',
#        'Employment Status', 'Department', 'Position', 'Pay Rate',
#        'Manager Name', 'Employee Source', 'Performance Score'],
#       dtype='object')

# %% [markdown]
# # Multicolinearity

# %%
data=data.drop(columns=['Date of Termination'])
data = data.fillna(0)
data.drop(data.tail(1).index,inplace=True)

# %%
data.keys()
# Out:
# Index(['Employee Number', 'State', 'Zip', 'DOB', 'Age', 'Sex', 'MaritalDesc',
#        'CitizenDesc', 'Hispanic/Latino', 'RaceDesc', 'Date of Hire',
#        'Reason For Term', 'Employment Status', 'Department', 'Position',
#        'Pay Rate', 'Manager Name', 'Employee Source',
#        'Performance Score_90-day meets', 'Performance Score_Exceeds',
#        'Performance Score_Exceptional', 'Performance Score_Fully Meets',
#        'Performance Score_N/A- too early to review',
#        'Performance Score_Needs Improvement', 'Performance Score_PIP'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(16,3))
 
for xcol, ax in zip(['Age','Performance Score_90-day meets', 'Performance Score_Exceeds','Performance Score_Exceptional', 'Performance Score_Fully Meets','Performance Score_N/A- too early to review','Performance Score_Needs Improvement', 'Performance Score_PIP'], axes):
    data.plot(kind='scatter', x=xcol, y='Pay Rate', ax=ax, alpha=0.4, color='b')

# %%
import warnings
warnings.filterwarnings('ignore')
fig = plt.figure(figsize = (10,14))
ax = fig.gca()
data.hist(ax = ax);

# %%
data[['Manager Name']].nunique()
# Out:
# Manager Name    20
# dtype: int64

# %%
managers = list(data['Manager Name'].value_counts().keys())
type(managers)
# Out:
# list

# %%
perf_score = list(df1['Performance Score'].value_counts().keys())
origin = list(data['Manager Name'].value_counts().keys())
origin_series = pd.Series(origin)

# %%
cat_origin = origin_series.astype('category')
cat_origin
# Out:
# 0          Kelley Spirea
# 1         Kissy Sullivan
# 2         Michael Albert
# 3           Elijiah Gray
# 4               Amy Dunn
# 5         Webster Butler
# 6          Ketsia Liebig
# 7          David Stanley
# 8         Brannon Miller
# 9             Janet King
# 10            Simon Roup
# 11            John Smith
# 12          Peter Monroe
# 13         Lynn Daneault
# 14       Alex Sweetwater
# 15    Brandon R. LeBlanc
# 16       Jennifer Zamora
# 17          Eric Dougall
# 18        Debra Houlihan
# 19    Board of Directors
# dtype: category
# Categories (20, object): [Alex Sweetwater, Amy Dunn, Board of Directors, Brandon R. LeBlanc, ..., Michael Albert, Peter Monroe, Simon Roup, Webster Butler]

# %%
cat_origin.cat.codes
# Out:
# 0     12
# 1     14
# 2     16
# 3      7
# 4      1
# 5     19
# 6     13
# 7      5
# 8      4
# 9      9
# 10    18
# 11    11
# 12    17
# 13    15
# 14     0
# 15     3
# 16    10
# 17     8
# 18     6
# 19     2
# dtype: int8

# %%
data = pd.get_dummies(data, columns = ['Manager Name'])
data.columns=['emp_num', 'state','zip','dob','age','sex','martial_status', 'citizen','hispanic','race','doh','reason_term','emp_status','department','pos','pay_rate','emp_source','perf_ninetymeets','perf_exceeds','perf_exceptional','perf_fullymeets','perf_tooearly','perf_needsimprovement','perf_pip','manager_alex','manager_amy','manager_board','manager_brandon','manager_brannon','manager_david','manager_debra','manager_elijiah','manager_eric','manager_janet','manager_jen','manager_john','manager_kelly','manager_ketisa','manager_kissy','manager_lynn','manager_michael','manager_peter','manager_simon','manager_webster']
data = data.drop(columns = ['emp_num','dob','reason_term'])

# %% [markdown]
# # Frequency Distribution
#
# **we want to determine the correlation between 2 categorical variables**
# - Manager name
# - performance scores

# %%
confusion_matrix = pd.crosstab(df1['Manager Name'], df1['Performance Score'])

# %%
plt.figure(figsize=(10,8))
ax = sns.heatmap(confusion_matrix,annot=True, linewidths=.5)
plt.title('Crosstab Frequency')
plt.tight_layout()
fig = ax.get_figure()
fig.savefig("images/frequency.png")

# %%
import scipy.stats as ss

# %%
def cramers_corrected_stat(confusion_matrix):
    """ calculate Cramers V statistic for categorial-categorial association.
        uses correction from Bergsma and Wicher, 
        Journal of the Korean Statistical Society 42 (2013): 323-328
    """
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)

# %%
df1.columns
# Out:
# Index(['Employee Name', 'Employee Number', 'State', 'Zip', 'DOB', 'Age', 'Sex',
#        'MaritalDesc', 'CitizenDesc', 'Hispanic/Latino', 'RaceDesc',
#        'Date of Hire', 'Date of Termination', 'Reason For Term',
#        'Employment Status', 'Department', 'Position', 'Pay Rate',
#        'Manager Name', 'Employee Source', 'Performance Score'],
#       dtype='object')

# %%
def cramers_stat(confusion_matrix):
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum()
    return np.sqrt(chi2 / (n*(min(confusion_matrix.shape)-1)))

result = cramers_stat(confusion_matrix)

# %%
result
# Out:
# Performance Score
# 90-day meets                0.844466
# Exceeds                     0.888555
# Exceptional                 1.567263
# Fully Meets                 0.358508
# N/A- too early to review    0.772969
# Needs Improvement           1.213997
# PIP                         1.567263
# dtype: float64

# %% [markdown]
# # 2. Overall Diverstiy within the Organization

# %%
diversity_df = pd.read_csv('datafiles/diversity.csv',index_col=0)

# %%
#simple age distribution
ax = sns.distplot(diversity_df['Age'])
plt.title('Age Distribution')
plt.tight_layout()
fig = ax.get_figure()
fig.savefig("images/age_dist.png")

# %%
diversity_df['Sex'].replace('male','Male',inplace=True)
diversity_df['Sex'].replace('Male',1,inplace=True)
diversity_df['Sex'].replace('Female',0,inplace=True)
diversity_df['male']=diversity_df['Sex']
diversity_df = diversity_df.drop(columns=['Sex'])
diversity_df = diversity_df.dropna()
diversity_df['MaritalDesc'].value_counts()
# Out:
# Single       127
# Married      119
# Divorced      30
# Separated     14
# widowed       11
# Name: MaritalDesc, dtype: int64

# %%
diversity_df['MaritalDesc'].replace(['Single','widowed','Divorced'],0,inplace=True)
diversity_df['MaritalDesc'].replace(['Married','Separated'],1,inplace=True)
diversity_df['married']=diversity_df['MaritalDesc']
diversity_df = diversity_df.drop(columns=['MaritalDesc'])

diversity_df=diversity_df.drop(columns=['CitizenDesc'])
diversity_df['Hispanic/Latino'].replace(['No','no'],0,inplace=True)
diversity_df['Hispanic/Latino'].replace(['Yes','yes'],1,inplace=True)

diversity_df['RaceDesc'].replace('White',1,inplace=True)
diversity_df['RaceDesc'].replace(['Black or African American', 'Asian', 'Two or more races','Hispanic','American Indian or Alaska Native'],0,inplace=True)
diversity_df['white'] = diversity_df['RaceDesc']
diversity_df=diversity_df.drop(columns=['RaceDesc'])

# %%
diversity_df['Employment Status'].value_counts()
# Out:
# Active                    174
# Voluntarily Terminated     88
# Terminated for Cause       14
# Leave of Absence           14
# Future Start               11
# Name: Employment Status, dtype: int64

# %%
diversity_df = pd.get_dummies(diversity_df, columns = ['Employment Status', 'Department'])

# %%
# diversity_df['emp_source'].unique()
diversity_df['emp_source'].replace(['Diversity Job Fair', 'Website Banner Ads', 'Internet Search',
       'Pay Per Click - Google', 'Monster.com', 'Other',
       'Employee Referral', 'Search Engine - Google Bing Yahoo',
       'Glassdoor', 'Vendor Referral', 'Professional Society',
       'Information Session', 'Company Intranet - Partner',
       'On-campus Recruiting', 'Billboard', 'MBTA ads', 'Word of Mouth',
       'Social Networks - Facebook Twitter etc',
       'On-line Web application', 'Newspager/Magazine', 'Pay Per Click',
       'Careerbuilder'],
        ['job_fair','web_banner','int_search','PPC_google','monster','other','referral',
         'int_search','glassdoor','vendor_referral','prof_society','info_session','company_partner',
        'campus_recruiting','ads','ads','word_of_mouth','social_network','web_application',
         'newspaper_magazine','PPC_google','careerbuilder'],inplace=True)

# %%
diversity_df=pd.get_dummies(diversity_df, columns = ['emp_source'])

# %%
diversity_df.columns=['age', 
                      'latino',
                      'pay_rate',
                      'emp_source',
                      'male',
                      'married',
                      'white',
                      'status_active',
                      'status_futurestart',
                     'status_leaveofabsence',
                     'status_term_for_cause',
                     'status_term_volun',
                     'dep_admin',
                     'dep_exec',
                     'dep_it',
                     'dep_production',
                     'dep_sales',
                     'dep_softengineering',
                     'dep_soft']
diversity_df['dep_software_engineering'] = diversity_df['dep_softengineering']+diversity_df['dep_soft']
diversity_df = diversity_df.drop(columns=['dep_softengineering','dep_soft'])

# %%
plt.figure(figsize=(20,10))
sns.heatmap(diversity_df.corr(),annot=True)
plt.title('Diversity within the Organization')
# Out:
# Text(0.5, 1, 'Diversity within the Organization')

# %% [markdown]
# # Multicollinearity of Features

# %%
diversity_df.head(1)
# Out:
#                age  latino  pay_rate          emp_source  male  married  \
# Employee Name
# Brown, Mia      32       0      28.5  Diversity Job Fair     0        1
#
#                white  status_active  status_futurestart  \
# Employee Name
# Brown, Mia         0              1                   0
#
#                status_leaveofabsence  status_term_for_cause  \
# Employee Name
# Brown, Mia                         0                      0
#
#                status_term_volun  dep_admin  dep_exec  dep_it  dep_production  \
# Employee Name
# Brown, Mia                     0          1         0       0               0
#
#                dep_sales  dep_software_engineering
# Employee Name
# Brown, Mia             0                         0

# %%
pd.plotting.scatter_matrix(diversity_df,figsize  = [9, 9]);
plt.show()

# %%
diversity_df.corr()
# Out:
#                                age    latino  pay_rate      male   married  \
# age                       1.000000 -0.050410  0.016798 -0.001973  0.019552
# latino                   -0.050410  1.000000  0.041918  0.027468 -0.077665
# pay_rate                  0.016798  0.041918  1.000000  0.123167  0.025662
# male                     -0.001973  0.027468  0.123167  1.000000 -0.069305
# married                   0.019552 -0.077665  0.025662 -0.069305  1.000000
# white                    -0.024027  0.007718 -0.098028 -0.002316  0.014511
# status_active            -0.098993  0.065170  0.174705  0.035207 -0.079701
# status_futurestart       -0.055587 -0.062373  0.022998 -0.058838  0.040627
# status_leaveofabsence     0.057120 -0.070733 -0.042853 -0.028972  0.121159
# status_term_for_cause    -0.036532 -0.016420  0.033530  0.002972 -0.037678
# status_term_volun         0.120885 -0.004678 -0.194864 -0.001916  0.031126
# dep_admin                -0.133886 -0.059368  0.014409 -0.008230  0.096359
# dep_exec                  0.158123  0.180278  0.187313 -0.049325  0.064889
# dep_it                   -0.033061  0.106238  0.367985  0.092194  0.036739
# dep_production            0.079711 -0.058141 -0.751054 -0.098427 -0.027609
# dep_sales                 0.003681  0.004376  0.553380  0.064632 -0.037366
# dep_software_engineering -0.065367 -0.059368  0.219042 -0.008230 -0.052954
#
#                              white  status_active  status_futurestart  \
# age                      -0.024027      -0.098993           -0.055587
# latino                    0.007718       0.065170           -0.062373
# pay_rate                 -0.098028       0.174705            0.022998
# male                     -0.002316       0.035207           -0.058838
# married                   0.014511      -0.079701            0.040627
# white                     1.000000       0.030202            0.002073
# status_active             0.030202       1.000000           -0.227966
# status_futurestart        0.002073      -0.227966            1.000000
# status_leaveofabsence    -0.125470      -0.258521           -0.043015
# status_term_for_cause    -0.027375      -0.258521           -0.043015
# status_term_volun         0.037118      -0.752358           -0.125184
# dep_admin                -0.050421       0.083302           -0.036104
# dep_exec                  0.044129       0.049325           -0.011244
# dep_it                    0.022476       0.045087            0.025894
# dep_production            0.099910      -0.207302            0.015276
# dep_sales                -0.126146       0.178823           -0.007741
# dep_software_engineering -0.050421       0.045766           -0.036104
#
#                           status_leaveofabsence  status_term_for_cause  \
# age                                    0.057120              -0.036532
# latino                                -0.070733              -0.016420
# pay_rate                              -0.042853               0.033530
# male                                  -0.028972               0.002972
# married                                0.121159              -0.037678
# white                                 -0.125470              -0.027375
# status_active                         -0.258521              -0.258521
# status_futurestart                    -0.043015              -0.043015
# status_leaveofabsence                  1.000000              -0.048780
# status_term_for_cause                 -0.048780               1.000000
# status_term_volun                     -0.141963              -0.141963
# dep_admin                             -0.040943              -0.040943
# dep_exec                              -0.012752              -0.012752
# dep_it                                 0.050270               0.096262
# dep_production                         0.045258              -0.057168
# dep_sales                             -0.074838              -0.022934
# dep_software_engineering              -0.040943               0.047084
#
#                           status_term_volun  dep_admin  dep_exec    dep_it  \
# age                                0.120885  -0.133886  0.158123 -0.033061
# latino                            -0.004678  -0.059368  0.180278  0.106238
# pay_rate                          -0.194864   0.014409  0.187313  0.367985
# male                              -0.001916  -0.008230 -0.049325  0.092194
# married                            0.031126   0.096359  0.064889  0.036739
# white                              0.037118  -0.050421  0.044129  0.022476
# status_active                     -0.752358   0.083302  0.049325  0.045087
# status_futurestart                -0.125184  -0.036104 -0.011244  0.025894
# status_leaveofabsence             -0.141963  -0.040943 -0.012752  0.050270
# status_term_for_cause             -0.141963  -0.040943 -0.012752  0.096262
# status_term_volun                  1.000000  -0.037642 -0.037110 -0.127481
# dep_admin                         -0.037642   1.000000 -0.010703 -0.073614
# dep_exec                          -0.037110  -0.010703  1.000000 -0.022927
# dep_it                            -0.127481  -0.073614 -0.022927  1.000000
# dep_production                     0.224298  -0.277232 -0.086343 -0.593876
# dep_sales                         -0.145703  -0.062813 -0.019563 -0.134556
# dep_software_engineering          -0.037642  -0.034364 -0.010703 -0.073614
#
#                           dep_production  dep_sales  dep_software_engineering
# age                             0.079711   0.003681                 -0.065367
# latino                         -0.058141   0.004376                 -0.059368
# pay_rate                       -0.751054   0.553380                  0.219042
# male                           -0.098427   0.064632                 -0.008230
# married                        -0.027609  -0.037366                 -0.052954
# white                           0.099910  -0.126146                 -0.050421
# status_active                  -0.207302   0.178823                  0.045766
# status_futurestart              0.015276  -0.007741                 -0.036104
# status_leaveofabsence           0.045258  -0.074838                 -0.040943
# status_term_for_cause          -0.057168  -0.022934                  0.047084
# status_term_volun               0.224298  -0.145703                 -0.037642
# dep_admin                      -0.277232  -0.062813                 -0.034364
# dep_exec                       -0.086343  -0.019563                 -0.010703
# dep_it                         -0.593876  -0.134556                 -0.073614
# dep_production                  1.000000  -0.506745                 -0.277232
# dep_sales                      -0.506745   1.000000                 -0.062813
# dep_software_engineering       -0.277232  -0.062813                  1.000000

# %%
abs(diversity_df.corr()) > 0.75
# Out:
#                             age  latino  pay_rate   male  married  white  \
# age                        True   False     False  False    False  False
# latino                    False    True     False  False    False  False
# pay_rate                  False   False      True  False    False  False
# male                      False   False     False   True    False  False
# married                   False   False     False  False     True  False
# white                     False   False     False  False    False   True
# status_active             False   False     False  False    False  False
# status_futurestart        False   False     False  False    False  False
# status_leaveofabsence     False   False     False  False    False  False
# status_term_for_cause     False   False     False  False    False  False
# status_term_volun         False   False     False  False    False  False
# dep_admin                 False   False     False  False    False  False
# dep_exec                  False   False     False  False    False  False
# dep_it                    False   False     False  False    False  False
# dep_production            False   False      True  False    False  False
# dep_sales                 False   False     False  False    False  False
# dep_software_engineering  False   False     False  False    False  False
#
#                           status_active  status_futurestart  \
# age                               False               False
# latino                            False               False
# pay_rate                          False               False
# male                              False               False
# married                           False               False
# white                             False               False
# status_active                      True               False
# status_futurestart                False                True
# status_leaveofabsence             False               False
# status_term_for_cause             False               False
# status_term_volun                  True               False
# dep_admin                         False               False
# dep_exec                          False               False
# dep_it                            False               False
# dep_production                    False               False
# dep_sales                         False               False
# dep_software_engineering          False               False
#
#                           status_leaveofabsence  status_term_for_cause  \
# age                                       False                  False
# latino                                    False                  False
# pay_rate                                  False                  False
# male                                      False                  False
# married                                   False                  False
# white                                     False                  False
# status_active                             False                  False
# status_futurestart                        False                  False
# status_leaveofabsence                      True                  False
# status_term_for_cause                     False                   True
# status_term_volun                         False                  False
# dep_admin                                 False                  False
# dep_exec                                  False                  False
# dep_it                                    False                  False
# dep_production                            False                  False
# dep_sales                                 False                  False
# dep_software_engineering                  False                  False
#
#                           status_term_volun  dep_admin  dep_exec  dep_it  \
# age                                   False      False     False   False
# latino                                False      False     False   False
# pay_rate                              False      False     False   False
# male                                  False      False     False   False
# married                               False      False     False   False
# white                                 False      False     False   False
# status_active                          True      False     False   False
# status_futurestart                    False      False     False   False
# status_leaveofabsence                 False      False     False   False
# status_term_for_cause                 False      False     False   False
# status_term_volun                      True      False     False   False
# dep_admin                             False       True     False   False
# dep_exec                              False      False      True   False
# dep_it                                False      False     False    True
# dep_production                        False      False     False   False
# dep_sales                             False      False     False   False
# dep_software_engineering              False      False     False   False
#
#                           dep_production  dep_sales  dep_software_engineering
# age                                False      False                     False
# latino                             False      False                     False
# pay_rate                            True      False                     False
# male                               False      False                     False
# married                            False      False                     False
# white                              False      False                     False
# status_active                      False      False                     False
# status_futurestart                 False      False                     False
# status_leaveofabsence              False      False                     False
# status_term_for_cause              False      False                     False
# status_term_volun                  False      False                     False
# dep_admin                          False      False                     False
# dep_exec                           False      False                     False
# dep_it                             False      False                     False
# dep_production                      True      False                     False
# dep_sales                          False       True                     False
# dep_software_engineering           False      False                      True

# %%
sns.heatmap(diversity_df.corr(), center=0)
#not much correlation... maybe between department and payrate

# %% [markdown]
# # Linear Regression

# %%
x_cols =['age','latino','male','married','white','status_active','status_futurestart','status_leaveofabsence','status_term_for_cause','status_term_volun','dep_admin','dep_exec','dep_it','dep_production','dep_sales','dep_software_engineering','emp_source_PPC_google', 'emp_source_ads','emp_source_campus_recruiting', 'emp_source_careerbuilder','emp_source_company_partner', 'emp_source_glassdoor','emp_source_info_session', 'emp_source_int_search','emp_source_job_fair', 'emp_source_monster','emp_source_newspaper_magazine', 'emp_source_other','emp_source_prof_society', 'emp_source_referral','emp_source_social_network', 'emp_source_vendor_referral','emp_source_web_application', 'emp_source_web_banner','emp_source_word_of_mouth']

# %%
outcome = 'pay_rate'
predictors = '+'.join(x_cols)
formula = outcome + '~' + predictors
model = ols(formula=formula, data=diversity_df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               pay_rate   R-squared:                       0.683
# Model:                            OLS   Adj. R-squared:                  0.646
# Method:                 Least Squares   F-statistic:                     18.08
# Date:                Thu, 20 Feb 2020   Prob (F-statistic):           5.96e-50
# Time:                        16:04:59   Log-Likelihood:                -1072.9
# No. Observations:                 301   AIC:                             2212.
# Df Residuals:                     268   BIC:                             2334.
# Df Model:                          32
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        32.0469      2.553     12.553      0.000      27.020      37.073
# age                               0.0629      0.065      0.974      0.331      -0.064       0.190
# latino                            0.2974      1.940      0.153      0.878      -3.521       4.116
# male                              1.9974      1.115      1.791      0.074      -0.199       4.194
# married                           0.8274      1.115      0.742      0.459      -1.367       3.022
# white                            -2.0471      1.248     -1.640      0.102      -4.504       0.410
# status_active                     5.9543      1.129      5.275      0.000       3.732       8.177
# status_futurestart                7.3341      2.493      2.942      0.004       2.427      12.242
# status_leaveofabsence             6.8283      2.271      3.007      0.003       2.358      11.299
# status_term_for_cause             5.9775      2.243      2.665      0.008       1.562      10.393
# status_term_volun                 5.9527      1.356      4.389      0.000       3.282       8.623
# dep_admin                        -8.5914      3.037     -2.829      0.005     -14.571      -2.612
# dep_exec                         36.5033      8.408      4.341      0.000      19.949      53.057
# dep_it                            1.6593      2.133      0.778      0.437      -2.540       5.858
# dep_production                  -18.1066      1.720    -10.527      0.000     -21.493     -14.720
# dep_sales                        13.1641      2.147      6.131      0.000       8.937      17.391
# dep_software_engineering          7.4182      2.924      2.537      0.012       1.661      13.175
# emp_source_PPC_google             2.4538      2.170      1.131      0.259      -1.819       6.727
# emp_source_ads                    0.4957      1.848      0.268      0.789      -3.143       4.134
# emp_source_campus_recruiting     -1.5916      2.756     -0.577      0.564      -7.019       3.835
# emp_source_careerbuilder          2.8108      8.735      0.322      0.748     -14.387      20.009
# emp_source_company_partner       18.9207      8.857      2.136      0.034       1.483      36.358
# emp_source_glassdoor             -0.8661      2.540     -0.341      0.733      -5.867       4.135
# emp_source_info_session          -5.2330      4.493     -1.165      0.245     -14.080       3.614
# emp_source_int_search             1.2153      1.882      0.646      0.519      -2.491       4.922
# emp_source_job_fair              -3.2143      2.186     -1.470      0.143      -7.519       1.090
# emp_source_monster                1.3523      2.039      0.663      0.508      -2.662       5.366
# emp_source_newspaper_magazine     0.3989      2.295      0.174      0.862      -4.120       4.918
# emp_source_other                  8.1707      3.082      2.651      0.008       2.103      14.238
# emp_source_prof_society           2.4603      2.226      1.105      0.270      -1.922       6.843
# emp_source_referral               3.3305      1.932      1.724      0.086      -0.474       7.135
# emp_source_social_network        -0.3960      2.833     -0.140      0.889      -5.975       5.183
# emp_source_vendor_referral        6.6729      2.599      2.567      0.011       1.556      11.790
# emp_source_web_application       -4.3602      8.721     -0.500      0.618     -21.530      12.810
# emp_source_web_banner             0.3934      2.764      0.142      0.887      -5.048       5.835
# emp_source_word_of_mouth         -0.9673      2.633     -0.367      0.714      -6.151       4.216
# ==============================================================================
# Omnibus:                      100.885   Durbin-Watson:                   0.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              287.695
# Skew:                           1.531   Prob(JB):                     3.37e-63
# Kurtosis:                       6.683   Cond. No.                     2.93e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.5e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
