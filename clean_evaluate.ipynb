# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
hr_data = pd.read_csv('HR_dataset.csv')

# %%
hr_data.columns=(['name', 'emp_num', 'state', 'zip', 'DOB', 'age', 'sex', 'marital_desc', 'citizen_desc', 'hispanic', 'race', 'date_of_hire', 'date_of_term', 'reason_for_term', 'emp_status', 'department', 'position', 'pay_rate', 'manager_name', 'employee_source', 'performance_score'])

# %%
hr_data.head()
# Out:
#                    name       emp_num state     zip       DOB   age     sex  \
# 0            Brown, Mia  1.103024e+09    MA  1450.0  11/24/85  32.0  Female
# 1  LaRotonda, William    1.106027e+09    MA  1460.0   4/26/84  33.0    Male
# 2      Steans, Tyrone    1.302053e+09    MA  2703.0    9/1/86  31.0    Male
# 3       Howard, Estelle  1.211051e+09    MA  2170.0   9/16/85  32.0  Female
# 4           Singh, Nan   1.307060e+09    MA  2330.0   5/19/88  29.0  Female
#
#   marital_desc citizen_desc hispanic  ... date_of_hire date_of_term  \
# 0      Married   US Citizen       No  ...     10/27/08          NaN
# 1     Divorced   US Citizen       No  ...       1/6/14          NaN
# 2       Single   US Citizen       No  ...      9/29/14          NaN
# 3      Married   US Citizen       No  ...      2/16/15      4/15/15
# 4       Single   US Citizen       No  ...       5/1/15          NaN
#
#         reason_for_term emp_status     department                  position  \
# 0  N/A - still employed     Active  Admin Offices              Accountant I
# 1  N/A - still employed     Active  Admin Offices              Accountant I
# 2  N/A - still employed     Active  Admin Offices              Accountant I
# 3  N/A - still employed     Active  Admin Offices  Administrative Assistant
# 4  N/A - still employed     Active  Admin Offices  Administrative Assistant
#
#   pay_rate        manager_name         employee_source  \
# 0    28.50  Brandon R. LeBlanc      Diversity Job Fair
# 1    23.00  Brandon R. LeBlanc      Website Banner Ads
# 2    29.00  Brandon R. LeBlanc         Internet Search
# 3    21.50  Brandon R. LeBlanc  Pay Per Click - Google
# 4    16.56  Brandon R. LeBlanc      Website Banner Ads
#
#           performance_score
# 0               Fully Meets
# 1               Fully Meets
# 2               Fully Meets
# 3  N/A- too early to review
# 4  N/A- too early to review
#
# [5 rows x 21 columns]

# %%
hr_data.isna().sum()
# Out:
# name                   1
# emp_num                1
# state                  1
# zip                    1
# DOB                    1
# age                    1
# sex                    1
# marital_desc           1
# citizen_desc           1
# hispanic               1
# race                   1
# date_of_hire           1
# date_of_term         199
# reason_for_term        1
# emp_status             1
# department             1
# position               1
# pay_rate               1
# manager_name           1
# employee_source        1
# performance_score      1
# dtype: int64

# %%
hr_data['sex'].replace('male','Male', inplace = True)

# %%
hr_data = hr_data[pd.notnull(hr_data['name'])]
hr_data = hr_data.fillna(0)

# %%
hr_data.shape
# Out:
# (301, 21)

# %%
from sklearn.preprocessing import LabelEncoder
gle = LabelEncoder()
employee_labels = gle.fit_transform(hr_data['emp_status'])
current_employee = {index: label for index, label in 
                  enumerate(gle.classes_)}

# %%
performance_chart = sns.barplot(x = 'performance_score', y = 'pay_rate', data=hr_data, palette='Set1', ci=None)
performance_chart.set_xticklabels(performance_chart.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Fully Meets'),
#  Text(0, 0, 'N/A- too early to review'),
#  Text(0, 0, '90-day meets'),
#  Text(0, 0, 'Exceptional'),
#  Text(0, 0, 'Needs Improvement'),
#  Text(0, 0, 'Exceeds'),
#  Text(0, 0, 'PIP')]

# %%
position_chart = sns.barplot(x = 'position', y = 'pay_rate', data=hr_data, palette='Set1', ci = None)
position_chart.set_xticklabels(position_chart.get_xticklabels(),rotation=90)
plt.show()

# %%
sns.barplot(x = 'sex', y = 'pay_rate', data=hr_data, ci=None )

# %%
df = hr_data.replace(np.nan,0)
df = hr_data.groupby(['manager_name'])['pay_rate'].mean()
df = df.sort_values(axis=0)

xlabel = 'Avg Pay_Rate'
ylabel = 'Manager'
title= "Manager's Team with the Highest Average Pay_rate"

ax = df.plot.barh(stacked = True)
ax.set(title = title, xlabel=xlabel, ylabel=ylabel)
plt.show()

# %%
df = hr_data.replace(np.nan,0)
df = hr_data.groupby(['manager_name'])['pay_rate'].count()
df = df.sort_values(axis=0)

xlabel = 'Count'
ylabel = 'Manager'
title= "Manager Team Count"

ax = df.plot.barh(stacked = True)
ax.set(title = title, xlabel=xlabel, ylabel=ylabel)
plt.show()

# %%
df = hr_data.replace(np.nan,0)
df = hr_data.groupby(['state'])['pay_rate'].mean()
df = df.sort_values(axis=0)
df = df.head(10)

xlabel = 'Avg Pay_Rate'
ylabel = 'State'
title= "State with the Highest Average Pay_rate"
fig = plt.figure(figsize=(5,5))

ax = df.plot.barh(stacked = True)
ax.set(title = title, xlabel=xlabel, ylabel=ylabel)
plt.show()

# %%
df = hr_data.replace(np.nan,0)
df = hr_data.groupby(['state'])['pay_rate'].count()
df = df.sort_values(axis=0)
df = df.tail(10)

xlabel = 'Avg Pay_Rate'
ylabel = 'State'
title= "State with the Most Amount of People"
fig = plt.figure(figsize=(5,5))

ax = df.plot.barh(stacked = True)
ax.set(title = title, xlabel=xlabel, ylabel=ylabel)
plt.show()

# %% [markdown]
# # Dummy Variables
# **we want to create dummy variables for sex and positions**
# - we drop the first column
#     - sex_female was dropped
#     - position Accountant 1 was dropped
#     - '90-day meets' performance score was dropped
#     - 'Alex Sweetwater'manager was dropped

# %%
performance_labels = gle.fit_transform(hr_data['performance_score'])
performances = {index: label for index, label in 
                  enumerate(gle.classes_)}

managers_labels = gle.fit_transform(hr_data['manager_name'])
managers = {index: label for index, label in 
                  enumerate(gle.classes_)}

# %%
hr_data = pd.get_dummies(hr_data, columns = ['sex','manager_name', 'position', 'performance_score'], drop_first=True)

# %%
hr_data = hr_data.drop(columns='emp_num')

# %%
hr_data.corr()
# Out:
#                                                  zip       age  pay_rate  \
# zip                                         1.000000 -0.013362  0.412814
# age                                        -0.013362  1.000000  0.016798
# pay_rate                                    0.412814  0.016798  1.000000
# sex_Male                                    0.056232 -0.001973  0.123167
# manager_name_Amy Dunn                      -0.074194  0.016781 -0.169995
# manager_name_Board of Directors            -0.022567  0.109486  0.144071
# manager_name_Brandon R. LeBlanc            -0.041815 -0.130455 -0.059490
# manager_name_Brannon Miller                -0.073724  0.064983 -0.162484
# manager_name_David Stanley                 -0.074353 -0.075242 -0.194891
# manager_name_Debra Houlihan                 0.013050 -0.103558  0.171958
# manager_name_Elijiah Gray                  -0.075195  0.024219 -0.178127
# manager_name_Eric Dougall                  -0.017234 -0.000626 -0.017153
# manager_name_Janet King                    -0.070508  0.075874  0.365943
# manager_name_Jennifer Zamora               -0.039069  0.087087  0.184178
# manager_name_John Smith                     0.464220  0.034149  0.355157
# manager_name_Kelley Spirea                 -0.075567  0.082835 -0.183992
# manager_name_Ketsia Liebig                 -0.074445 -0.047489 -0.175146
# manager_name_Kissy Sullivan                -0.076681 -0.031538 -0.177278
# manager_name_Lynn Daneault                  0.614795 -0.002062  0.343948
# manager_name_Michael Albert                -0.074339 -0.022960 -0.178749
# manager_name_Peter Monroe                  -0.052523 -0.024163  0.207065
# manager_name_Simon Roup                     0.002484 -0.058546  0.218888
# manager_name_Webster Butler                -0.073214  0.060601 -0.179052
# position_Administrative Assistant          -0.026874 -0.092320 -0.073944
# position_Area Sales Manager                 0.779477  0.023700  0.506422
# position_CIO                               -0.015624 -0.003545  0.130304
# position_Database Administrator             0.016219 -0.095419  0.122540
# position_Director of Operations            -0.015749 -0.029412  0.111300
# position_Director of Sales                 -0.012791  0.080523  0.111300
# position_IT Director                       -0.017669 -0.010012  0.130304
# position_IT Manager - DB                   -0.021508  0.095745  0.058064
# position_IT Manager - Infra                -0.015399 -0.048812  0.122702
# position_IT Manager - Support              -0.016234  0.054656  0.126503
# position_IT Support                        -0.017234 -0.000626 -0.017153
# position_Network Engineer                  -0.047817 -0.093806  0.103580
# position_President & CEO                   -0.016180  0.158123  0.187313
# position_Production Manager                -0.060235  0.094227  0.275711
# position_Production Technician I           -0.243854  0.046693 -0.693912
# position_Production Technician II          -0.131267 -0.011631 -0.168869
# position_Sales Manager                      0.013050 -0.103558  0.171958
# position_Shared Services Manager           -0.023634 -0.050825  0.130746
# position_Software Engineer                 -0.047208 -0.095991  0.235266
# position_Software Engineering Manager      -0.015230  0.080523 -0.014120
# position_Sr. Accountant                    -0.021217 -0.041664  0.022799
# position_Sr. DBA                           -0.023785  0.051368  0.223722
# position_Sr. Network Engineer              -0.022822  0.085187  0.203153
# performance_score_Exceeds                   0.013356  0.062327 -0.014627
# performance_score_Exceptional               0.037860 -0.017334  0.089647
# performance_score_Fully Meets               0.000617  0.123856 -0.002768
# performance_score_N/A- too early to review -0.055221 -0.161248 -0.065077
# performance_score_Needs Improvement        -0.032705 -0.070494  0.029922
# performance_score_PIP                       0.162007  0.021994 -0.014045
#
#                                             sex_Male  manager_name_Amy Dunn  \
# zip                                         0.056232              -0.074194
# age                                        -0.001973               0.016781
# pay_rate                                    0.123167              -0.169995
# sex_Male                                    1.000000              -0.022721
# manager_name_Amy Dunn                      -0.022721               1.000000
# manager_name_Board of Directors            -0.069873              -0.022398
# manager_name_Brandon R. LeBlanc            -0.042558              -0.042258
# manager_name_Brannon Miller                -0.022721              -0.075000
# manager_name_David Stanley                 -0.049127              -0.075000
# manager_name_Debra Houlihan                -0.017999              -0.027478
# manager_name_Elijiah Gray                  -0.162368              -0.076902
# manager_name_Eric Dougall                  -0.040400              -0.031782
# manager_name_Janet King                     0.054865              -0.071086
# manager_name_Jennifer Zamora                0.166931              -0.039057
# manager_name_John Smith                     0.066859              -0.060486
# manager_name_Kelley Spirea                  0.070237              -0.076902
# manager_name_Ketsia Liebig                 -0.049127              -0.075000
# manager_name_Kissy Sullivan                -0.007298              -0.076902
# manager_name_Lynn Daneault                  0.050133              -0.058184
# manager_name_Michael Albert                 0.018547              -0.076902
# manager_name_Peter Monroe                   0.066859              -0.060486
# manager_name_Simon Roup                     0.024107              -0.067003
# manager_name_Webster Butler                 0.003685              -0.075000
# position_Administrative Assistant          -0.085720              -0.027478
# position_Area Sales Manager                 0.084937              -0.085968
# position_CIO                               -0.049325              -0.015811
# position_Database Administrator             0.017041              -0.058184
# position_Director of Operations            -0.049325              -0.015811
# position_Director of Sales                 -0.049325              -0.015811
# position_IT Director                        0.067579              -0.015811
# position_IT Manager - DB                    0.095731              -0.022398
# position_IT Manager - Infra                 0.067579              -0.015811
# position_IT Manager - Support               0.067579              -0.015811
# position_IT Support                        -0.040400              -0.031782
# position_Network Engineer                   0.047503              -0.048080
# position_President & CEO                   -0.049325              -0.015811
# position_Production Manager                 0.066859              -0.060486
# position_Production Technician I           -0.059232               0.144426
# position_Production Technician II          -0.069534               0.067344
# position_Sales Manager                     -0.017999              -0.027478
# position_Shared Services Manager            0.095731              -0.022398
# position_Software Engineer                 -0.031494              -0.048080
# position_Software Engineering Manager       0.067579              -0.015811
# position_Sr. Accountant                    -0.069873              -0.022398
# position_Sr. DBA                            0.018346              -0.031782
# position_Sr. Network Engineer               0.046863              -0.035593
# performance_score_Exceeds                   0.004309               0.002088
# performance_score_Exceptional               0.008005               0.028492
# performance_score_Fully Meets               0.019419              -0.026352
# performance_score_N/A- too early to review -0.094474               0.096059
# performance_score_Needs Improvement         0.113490              -0.062718
# performance_score_PIP                       0.008005               0.028492
#
#                                             manager_name_Board of Directors  \
# zip                                                               -0.022567
# age                                                                0.109486
# pay_rate                                                           0.144071
# sex_Male                                                          -0.069873
# manager_name_Amy Dunn                                             -0.022398
# manager_name_Board of Directors                                    1.000000
# manager_name_Brandon R. LeBlanc                                   -0.012620
# manager_name_Brannon Miller                                       -0.022398
# manager_name_David Stanley                                        -0.022398
# manager_name_Debra Houlihan                                       -0.008206
# manager_name_Elijiah Gray                                         -0.022966
# manager_name_Eric Dougall                                         -0.009491
# manager_name_Janet King                                           -0.021229
# manager_name_Jennifer Zamora                                      -0.011664
# manager_name_John Smith                                           -0.018064
# manager_name_Kelley Spirea                                        -0.022966
# manager_name_Ketsia Liebig                                        -0.022398
# manager_name_Kissy Sullivan                                       -0.022966
# manager_name_Lynn Daneault                                        -0.017376
# manager_name_Michael Albert                                       -0.022966
# manager_name_Peter Monroe                                         -0.018064
# manager_name_Simon Roup                                           -0.020010
# manager_name_Webster Butler                                       -0.022398
# position_Administrative Assistant                                 -0.008206
# position_Area Sales Manager                                       -0.025674
# position_CIO                                                      -0.004722
# position_Database Administrator                                   -0.017376
# position_Director of Operations                                   -0.004722
# position_Director of Sales                                        -0.004722
# position_IT Director                                              -0.004722
# position_IT Manager - DB                                          -0.006689
# position_IT Manager - Infra                                       -0.004722
# position_IT Manager - Support                                     -0.004722
# position_IT Support                                               -0.009491
# position_Network Engineer                                         -0.014359
# position_President & CEO                                           0.705927
# position_Production Manager                                       -0.018064
# position_Production Technician I                                  -0.074252
# position_Production Technician II                                 -0.039530
# position_Sales Manager                                            -0.008206
# position_Shared Services Manager                                  -0.006689
# position_Software Engineer                                        -0.014359
# position_Software Engineering Manager                             -0.004722
# position_Sr. Accountant                                            0.496656
# position_Sr. DBA                                                  -0.009491
# position_Sr. Network Engineer                                     -0.010630
# performance_score_Exceeds                                         -0.026193
# performance_score_Exceptional                                     -0.014359
# performance_score_Fully Meets                                      0.070829
# performance_score_N/A- too early to review                        -0.030618
# performance_score_Needs Improvement                               -0.018730
# performance_score_PIP                                             -0.014359
#
#                                             manager_name_Brandon R. LeBlanc  \
# zip                                                           -4.181455e-02
# age                                                           -1.304554e-01
# pay_rate                                                      -5.948983e-02
# sex_Male                                                      -4.255815e-02
# manager_name_Amy Dunn                                         -4.225771e-02
# manager_name_Board of Directors                               -1.261987e-02
# manager_name_Brandon R. LeBlanc                                1.000000e+00
# manager_name_Brannon Miller                                   -4.225771e-02
# manager_name_David Stanley                                    -4.225771e-02
# manager_name_Debra Houlihan                                   -1.548203e-02
# manager_name_Elijiah Gray                                     -4.332959e-02
# manager_name_Eric Dougall                                     -1.790718e-02
# manager_name_Janet King                                       -4.005231e-02
# manager_name_Jennifer Zamora                                  -2.200594e-02
# manager_name_John Smith                                       -3.407991e-02
# manager_name_Kelley Spirea                                    -4.332959e-02
# manager_name_Ketsia Liebig                                    -4.225771e-02
# manager_name_Kissy Sullivan                                   -4.332959e-02
# manager_name_Lynn Daneault                                    -3.278316e-02
# manager_name_Michael Albert                                   -4.332959e-02
# manager_name_Peter Monroe                                     -3.407991e-02
# manager_name_Simon Roup                                       -3.775206e-02
# manager_name_Webster Butler                                   -4.225771e-02
# position_Administrative Assistant                              6.502452e-01
# position_Area Sales Manager                                   -4.843753e-02
# position_CIO                                                  -8.908708e-03
# position_Database Administrator                               -3.278316e-02
# position_Director of Operations                               -8.908708e-03
# position_Director of Sales                                    -8.908708e-03
# position_IT Director                                          -8.908708e-03
# position_IT Manager - DB                                      -1.261987e-02
# position_IT Manager - Infra                                   -8.908708e-03
# position_IT Manager - Support                                 -8.908708e-03
# position_IT Support                                           -1.790718e-02
# position_Network Engineer                                     -2.708976e-02
# position_President & CEO                                      -8.908708e-03
# position_Production Manager                                   -3.407991e-02
# position_Production Technician I                              -1.400886e-01
# position_Production Technician II                             -7.457923e-02
# position_Sales Manager                                        -1.548203e-02
# position_Shared Services Manager                              -1.261987e-02
# position_Software Engineer                                    -2.708976e-02
# position_Software Engineering Manager                         -8.908708e-03
# position_Sr. Accountant                                        2.587073e-01
# position_Sr. DBA                                              -1.790718e-02
# position_Sr. Network Engineer                                 -2.005462e-02
# performance_score_Exceeds                                     -4.941662e-02
# performance_score_Exceptional                                 -2.708976e-02
# performance_score_Fully Meets                                  1.483598e-17
# performance_score_N/A- too early to review                     7.650126e-02
# performance_score_Needs Improvement                           -3.533767e-02
# performance_score_PIP                                         -2.708976e-02
#
#                                             manager_name_Brannon Miller  \
# zip                                                           -0.073724
# age                                                            0.064983
# pay_rate                                                      -0.162484
# sex_Male                                                      -0.022721
# manager_name_Amy Dunn                                         -0.075000
# manager_name_Board of Directors                               -0.022398
# manager_name_Brandon R. LeBlanc                               -0.042258
# manager_name_Brannon Miller                                    1.000000
# manager_name_David Stanley                                    -0.075000
# manager_name_Debra Houlihan                                   -0.027478
# manager_name_Elijiah Gray                                     -0.076902
# manager_name_Eric Dougall                                     -0.031782
# manager_name_Janet King                                       -0.071086
# manager_name_Jennifer Zamora                                  -0.039057
# manager_name_John Smith                                       -0.060486
# manager_name_Kelley Spirea                                    -0.076902
# manager_name_Ketsia Liebig                                    -0.075000
# manager_name_Kissy Sullivan                                   -0.076902
# manager_name_Lynn Daneault                                    -0.058184
# manager_name_Michael Albert                                   -0.076902
# manager_name_Peter Monroe                                     -0.060486
# manager_name_Simon Roup                                       -0.067003
# manager_name_Webster Butler                                   -0.075000
# position_Administrative Assistant                             -0.027478
# position_Area Sales Manager                                   -0.085968
# position_CIO                                                  -0.015811
# position_Database Administrator                               -0.058184
# position_Director of Operations                               -0.015811
# position_Director of Sales                                    -0.015811
# position_IT Director                                          -0.015811
# position_IT Manager - DB                                      -0.022398
# position_IT Manager - Infra                                   -0.015811
# position_IT Manager - Support                                 -0.015811
# position_IT Support                                           -0.031782
# position_Network Engineer                                     -0.048080
# position_President & CEO                                      -0.015811
# position_Production Manager                                   -0.060486
# position_Production Technician I                               0.144426
# position_Production Technician II                              0.067344
# position_Sales Manager                                        -0.027478
# position_Shared Services Manager                              -0.022398
# position_Software Engineer                                    -0.048080
# position_Software Engineering Manager                         -0.015811
# position_Sr. Accountant                                       -0.022398
# position_Sr. DBA                                              -0.031782
# position_Sr. Network Engineer                                 -0.035593
# performance_score_Exceeds                                      0.136779
# performance_score_Exceptional                                  0.105063
# performance_score_Fully Meets                                 -0.105409
# performance_score_N/A- too early to review                    -0.102525
# performance_score_Needs Improvement                           -0.002787
# performance_score_PIP                                          0.258205
#
#                                             manager_name_David Stanley  \
# zip                                                          -0.074353
# age                                                          -0.075242
# pay_rate                                                     -0.194891
# sex_Male                                                     -0.049127
# manager_name_Amy Dunn                                        -0.075000
# manager_name_Board of Directors                              -0.022398
# manager_name_Brandon R. LeBlanc                              -0.042258
# manager_name_Brannon Miller                                  -0.075000
# manager_name_David Stanley                                    1.000000
# manager_name_Debra Houlihan                                  -0.027478
# manager_name_Elijiah Gray                                    -0.076902
# manager_name_Eric Dougall                                    -0.031782
# manager_name_Janet King                                      -0.071086
# manager_name_Jennifer Zamora                                 -0.039057
# manager_name_John Smith                                      -0.060486
# manager_name_Kelley Spirea                                   -0.076902
# manager_name_Ketsia Liebig                                   -0.075000
# manager_name_Kissy Sullivan                                  -0.076902
# manager_name_Lynn Daneault                                   -0.058184
# manager_name_Michael Albert                                  -0.076902
# manager_name_Peter Monroe                                    -0.060486
# manager_name_Simon Roup                                      -0.067003
# manager_name_Webster Butler                                  -0.075000
# position_Administrative Assistant                            -0.027478
# position_Area Sales Manager                                  -0.085968
# position_CIO                                                 -0.015811
# position_Database Administrator                              -0.058184
# position_Director of Operations                              -0.015811
# position_Director of Sales                                   -0.015811
# position_IT Director                                         -0.015811
# position_IT Manager - DB                                     -0.022398
# position_IT Manager - Infra                                  -0.015811
# position_IT Manager - Support                                -0.015811
# position_IT Support                                          -0.031782
# position_Network Engineer                                    -0.048080
# position_President & CEO                                     -0.015811
# position_Production Manager                                  -0.060486
# position_Production Technician I                              0.144426
# position_Production Technician II                             0.067344
# position_Sales Manager                                       -0.027478
# position_Shared Services Manager                             -0.022398
# position_Software Engineer                                   -0.048080
# position_Software Engineering Manager                        -0.015811
# position_Sr. Accountant                                      -0.022398
# position_Sr. DBA                                             -0.031782
# position_Sr. Network Engineer                                -0.035593
# performance_score_Exceeds                                    -0.042809
# performance_score_Exceptional                                -0.048080
# performance_score_Fully Meets                                 0.079057
# performance_score_N/A- too early to review                    0.056343
# performance_score_Needs Improvement                          -0.062718
# performance_score_PIP                                        -0.048080
#
#                                             manager_name_Debra Houlihan  ...  \
# zip                                                            0.013050  ...
# age                                                           -0.103558  ...
# pay_rate                                                       0.171958  ...
# sex_Male                                                      -0.017999  ...
# manager_name_Amy Dunn                                         -0.027478  ...
# manager_name_Board of Directors                               -0.008206  ...
# manager_name_Brandon R. LeBlanc                               -0.015482  ...
# manager_name_Brannon Miller                                   -0.027478  ...
# manager_name_David Stanley                                    -0.027478  ...
# manager_name_Debra Houlihan                                    1.000000  ...
# manager_name_Elijiah Gray                                     -0.028175  ...
# manager_name_Eric Dougall                                     -0.011644  ...
# manager_name_Janet King                                       -0.026044  ...
# manager_name_Jennifer Zamora                                  -0.014309  ...
# manager_name_John Smith                                       -0.022160  ...
# manager_name_Kelley Spirea                                    -0.028175  ...
# manager_name_Ketsia Liebig                                    -0.027478  ...
# manager_name_Kissy Sullivan                                   -0.028175  ...
# manager_name_Lynn Daneault                                    -0.021317  ...
# manager_name_Michael Albert                                   -0.028175  ...
# manager_name_Peter Monroe                                     -0.022160  ...
# manager_name_Simon Roup                                       -0.024548  ...
# manager_name_Webster Butler                                   -0.027478  ...
# position_Administrative Assistant                             -0.010067  ...
# position_Area Sales Manager                                   -0.031496  ...
# position_CIO                                                  -0.005793  ...
# position_Database Administrator                               -0.021317  ...
# position_Director of Operations                               -0.005793  ...
# position_Director of Sales                                    -0.005793  ...
# position_IT Director                                          -0.005793  ...
# position_IT Manager - DB                                      -0.008206  ...
# position_IT Manager - Infra                                   -0.005793  ...
# position_IT Manager - Support                                 -0.005793  ...
# position_IT Support                                           -0.011644  ...
# position_Network Engineer                                     -0.017615  ...
# position_President & CEO                                      -0.005793  ...
# position_Production Manager                                   -0.022160  ...
# position_Production Technician I                              -0.091092  ...
# position_Production Technician II                             -0.048495  ...
# position_Sales Manager                                         1.000000  ...
# position_Shared Services Manager                              -0.008206  ...
# position_Software Engineer                                    -0.017615  ...
# position_Software Engineering Manager                         -0.005793  ...
# position_Sr. Accountant                                       -0.008206  ...
# position_Sr. DBA                                              -0.011644  ...
# position_Sr. Network Engineer                                 -0.013040  ...
# performance_score_Exceeds                                     -0.032133  ...
# performance_score_Exceptional                                 -0.017615  ...
# performance_score_Fully Meets                                  0.019309  ...
# performance_score_N/A- too early to review                    -0.037562  ...
# performance_score_Needs Improvement                            0.130720  ...
# performance_score_PIP                                         -0.017615  ...
#
#                                             position_Software Engineering Manager  \
# zip                                                                     -0.015230
# age                                                                      0.080523
# pay_rate                                                                -0.014120
# sex_Male                                                                 0.067579
# manager_name_Amy Dunn                                                   -0.015811
# manager_name_Board of Directors                                         -0.004722
# manager_name_Brandon R. LeBlanc                                         -0.008909
# manager_name_Brannon Miller                                             -0.015811
# manager_name_David Stanley                                              -0.015811
# manager_name_Debra Houlihan                                             -0.005793
# manager_name_Elijiah Gray                                               -0.016212
# manager_name_Eric Dougall                                               -0.006700
# manager_name_Janet King                                                 -0.014986
# manager_name_Jennifer Zamora                                             0.404832
# manager_name_John Smith                                                 -0.012752
# manager_name_Kelley Spirea                                              -0.016212
# manager_name_Ketsia Liebig                                              -0.015811
# manager_name_Kissy Sullivan                                             -0.016212
# manager_name_Lynn Daneault                                              -0.012266
# manager_name_Michael Albert                                             -0.016212
# manager_name_Peter Monroe                                               -0.012752
# manager_name_Simon Roup                                                 -0.014126
# manager_name_Webster Butler                                             -0.015811
# position_Administrative Assistant                                       -0.005793
# position_Area Sales Manager                                             -0.018124
# position_CIO                                                            -0.003333
# position_Database Administrator                                         -0.012266
# position_Director of Operations                                         -0.003333
# position_Director of Sales                                              -0.003333
# position_IT Director                                                    -0.003333
# position_IT Manager - DB                                                -0.004722
# position_IT Manager - Infra                                             -0.003333
# position_IT Manager - Support                                           -0.003333
# position_IT Support                                                     -0.006700
# position_Network Engineer                                               -0.010136
# position_President & CEO                                                -0.003333
# position_Production Manager                                             -0.012752
# position_Production Technician I                                        -0.052416
# position_Production Technician II                                       -0.027905
# position_Sales Manager                                                  -0.005793
# position_Shared Services Manager                                        -0.004722
# position_Software Engineer                                              -0.010136
# position_Software Engineering Manager                                    1.000000
# position_Sr. Accountant                                                 -0.004722
# position_Sr. DBA                                                        -0.006700
# position_Sr. Network Engineer                                           -0.007504
# performance_score_Exceeds                                               -0.018490
# performance_score_Exceptional                                           -0.010136
# performance_score_Fully Meets                                            0.050000
# performance_score_N/A- too early to review                              -0.021614
# performance_score_Needs Improvement                                     -0.013222
# performance_score_PIP                                                   -0.010136
#
#                                             position_Sr. Accountant  \
# zip                                                       -0.021217
# age                                                       -0.041664
# pay_rate                                                   0.022799
# sex_Male                                                  -0.069873
# manager_name_Amy Dunn                                     -0.022398
# manager_name_Board of Directors                            0.496656
# manager_name_Brandon R. LeBlanc                            0.258707
# manager_name_Brannon Miller                               -0.022398
# manager_name_David Stanley                                -0.022398
# manager_name_Debra Houlihan                               -0.008206
# manager_name_Elijiah Gray                                 -0.022966
# manager_name_Eric Dougall                                 -0.009491
# manager_name_Janet King                                   -0.021229
# manager_name_Jennifer Zamora                              -0.011664
# manager_name_John Smith                                   -0.018064
# manager_name_Kelley Spirea                                -0.022966
# manager_name_Ketsia Liebig                                -0.022398
# manager_name_Kissy Sullivan                               -0.022966
# manager_name_Lynn Daneault                                -0.017376
# manager_name_Michael Albert                               -0.022966
# manager_name_Peter Monroe                                 -0.018064
# manager_name_Simon Roup                                   -0.020010
# manager_name_Webster Butler                               -0.022398
# position_Administrative Assistant                         -0.008206
# position_Area Sales Manager                               -0.025674
# position_CIO                                              -0.004722
# position_Database Administrator                           -0.017376
# position_Director of Operations                           -0.004722
# position_Director of Sales                                -0.004722
# position_IT Director                                      -0.004722
# position_IT Manager - DB                                  -0.006689
# position_IT Manager - Infra                               -0.004722
# position_IT Manager - Support                             -0.004722
# position_IT Support                                       -0.009491
# position_Network Engineer                                 -0.014359
# position_President & CEO                                  -0.004722
# position_Production Manager                               -0.018064
# position_Production Technician I                          -0.074252
# position_Production Technician II                         -0.039530
# position_Sales Manager                                    -0.008206
# position_Shared Services Manager                          -0.006689
# position_Software Engineer                                -0.014359
# position_Software Engineering Manager                     -0.004722
# position_Sr. Accountant                                    1.000000
# position_Sr. DBA                                          -0.009491
# position_Sr. Network Engineer                             -0.010630
# performance_score_Exceeds                                 -0.026193
# performance_score_Exceptional                             -0.014359
# performance_score_Fully Meets                             -0.011805
# performance_score_N/A- too early to review                -0.030618
# performance_score_Needs Improvement                       -0.018730
# performance_score_PIP                                     -0.014359
#
#                                             position_Sr. DBA  \
# zip                                                -0.023785
# age                                                 0.051368
# pay_rate                                            0.223722
# sex_Male                                            0.018346
# manager_name_Amy Dunn                              -0.031782
# manager_name_Board of Directors                    -0.009491
# manager_name_Brandon R. LeBlanc                    -0.017907
# manager_name_Brannon Miller                        -0.031782
# manager_name_David Stanley                         -0.031782
# manager_name_Debra Houlihan                        -0.011644
# manager_name_Elijiah Gray                          -0.032588
# manager_name_Eric Dougall                          -0.013468
# manager_name_Janet King                            -0.030123
# manager_name_Jennifer Zamora                       -0.016551
# manager_name_John Smith                            -0.025632
# manager_name_Kelley Spirea                         -0.032588
# manager_name_Ketsia Liebig                         -0.031782
# manager_name_Kissy Sullivan                        -0.032588
# manager_name_Lynn Daneault                         -0.024656
# manager_name_Michael Albert                        -0.032588
# manager_name_Peter Monroe                          -0.025632
# manager_name_Simon Roup                             0.474336
# manager_name_Webster Butler                        -0.031782
# position_Administrative Assistant                  -0.011644
# position_Area Sales Manager                        -0.036430
# position_CIO                                       -0.006700
# position_Database Administrator                    -0.024656
# position_Director of Operations                    -0.006700
# position_Director of Sales                         -0.006700
# position_IT Director                               -0.006700
# position_IT Manager - DB                           -0.009491
# position_IT Manager - Infra                        -0.006700
# position_IT Manager - Support                      -0.006700
# position_IT Support                                -0.013468
# position_Network Engineer                          -0.020374
# position_President & CEO                           -0.006700
# position_Production Manager                        -0.025632
# position_Production Technician I                   -0.105361
# position_Production Technician II                  -0.056091
# position_Sales Manager                             -0.011644
# position_Shared Services Manager                   -0.009491
# position_Software Engineer                         -0.020374
# position_Software Engineering Manager              -0.006700
# position_Sr. Accountant                            -0.009491
# position_Sr. DBA                                    1.000000
# position_Sr. Network Engineer                      -0.015083
# performance_score_Exceeds                          -0.037166
# performance_score_Exceptional                      -0.020374
# performance_score_Fully Meets                      -0.016751
# performance_score_N/A- too early to review          0.044914
# performance_score_Needs Improvement                -0.026578
# performance_score_PIP                              -0.020374
#
#                                             position_Sr. Network Engineer  \
# zip                                                             -0.022822
# age                                                              0.085187
# pay_rate                                                         0.203153
# sex_Male                                                         0.046863
# manager_name_Amy Dunn                                           -0.035593
# manager_name_Board of Directors                                 -0.010630
# manager_name_Brandon R. LeBlanc                                 -0.020055
# manager_name_Brannon Miller                                     -0.035593
# manager_name_David Stanley                                      -0.035593
# manager_name_Debra Houlihan                                     -0.013040
# manager_name_Elijiah Gray                                       -0.036496
# manager_name_Eric Dougall                                       -0.015083
# manager_name_Janet King                                         -0.033736
# manager_name_Jennifer Zamora                                    -0.018535
# manager_name_John Smith                                         -0.028705
# manager_name_Kelley Spirea                                      -0.036496
# manager_name_Ketsia Liebig                                      -0.035593
# manager_name_Kissy Sullivan                                     -0.036496
# manager_name_Lynn Daneault                                      -0.027613
# manager_name_Michael Albert                                     -0.036496
# manager_name_Peter Monroe                                        0.588459
# manager_name_Simon Roup                                         -0.031798
# manager_name_Webster Butler                                     -0.035593
# position_Administrative Assistant                               -0.013040
# position_Area Sales Manager                                     -0.040799
# position_CIO                                                    -0.007504
# position_Database Administrator                                 -0.027613
# position_Director of Operations                                 -0.007504
# position_Director of Sales                                      -0.007504
# position_IT Director                                            -0.007504
# position_IT Manager - DB                                        -0.010630
# position_IT Manager - Infra                                     -0.007504
# position_IT Manager - Support                                   -0.007504
# position_IT Support                                             -0.015083
# position_Network Engineer                                       -0.022818
# position_President & CEO                                        -0.007504
# position_Production Manager                                     -0.028705
# position_Production Technician I                                -0.117996
# position_Production Technician II                               -0.062818
# position_Sales Manager                                          -0.013040
# position_Shared Services Manager                                -0.010630
# position_Software Engineer                                      -0.022818
# position_Software Engineering Manager                           -0.007504
# position_Sr. Accountant                                         -0.010630
# position_Sr. DBA                                                -0.015083
# position_Sr. Network Engineer                                    1.000000
# performance_score_Exceeds                                       -0.041623
# performance_score_Exceptional                                   -0.022818
# performance_score_Fully Meets                                   -0.045023
# performance_score_N/A- too early to review                       0.109674
# performance_score_Needs Improvement                             -0.029765
# performance_score_PIP                                           -0.022818
#
#                                             performance_score_Exceeds  \
# zip                                                          0.013356
# age                                                          0.062327
# pay_rate                                                    -0.014627
# sex_Male                                                     0.004309
# manager_name_Amy Dunn                                        0.002088
# manager_name_Board of Directors                             -0.026193
# manager_name_Brandon R. LeBlanc                             -0.049417
# manager_name_Brannon Miller                                  0.136779
# manager_name_David Stanley                                  -0.042809
# manager_name_Debra Houlihan                                 -0.032133
# manager_name_Elijiah Gray                                   -0.002044
# manager_name_Eric Dougall                                    0.062718
# manager_name_Janet King                                      0.057971
# manager_name_Jennifer Zamora                                 0.036158
# manager_name_John Smith                                     -0.070733
# manager_name_Kelley Spirea                                   0.041899
# manager_name_Ketsia Liebig                                   0.002088
# manager_name_Kissy Sullivan                                 -0.045987
# manager_name_Lynn Daneault                                   0.044489
# manager_name_Michael Albert                                 -0.002044
# manager_name_Peter Monroe                                   -0.070733
# manager_name_Simon Roup                                     -0.078354
# manager_name_Webster Butler                                  0.002088
# position_Administrative Assistant                           -0.032133
# position_Area Sales Manager                                 -0.020479
# position_CIO                                                -0.018490
# position_Database Administrator                             -0.068041
# position_Director of Operations                              0.180278
# position_Director of Sales                                  -0.018490
# position_IT Director                                        -0.018490
# position_IT Manager - DB                                    -0.026193
# position_IT Manager - Infra                                 -0.018490
# position_IT Manager - Support                                0.180278
# position_IT Support                                          0.062718
# position_Network Engineer                                   -0.056225
# position_President & CEO                                    -0.018490
# position_Production Manager                                  0.037893
# position_Production Technician I                             0.030999
# position_Production Technician II                            0.020367
# position_Sales Manager                                      -0.032133
# position_Shared Services Manager                            -0.026193
# position_Software Engineer                                   0.010933
# position_Software Engineering Manager                       -0.018490
# position_Sr. Accountant                                     -0.026193
# position_Sr. DBA                                            -0.037166
# position_Sr. Network Engineer                               -0.041623
# performance_score_Exceeds                                    1.000000
# ...
# manager_name_Eric Dougall                                    4.187658e-02
# manager_name_Janet King                                      5.915607e-02
# manager_name_Jennifer Zamora                                -2.058467e-02
# manager_name_John Smith                                      9.563651e-02
# manager_name_Kelley Spirea                                   6.263901e-02
# manager_name_Ketsia Liebig                                   5.270463e-02
# manager_name_Kissy Sullivan                                  3.684647e-02
# manager_name_Lynn Daneault                                   1.887128e-02
# manager_name_Michael Albert                                 -9.211619e-02
# manager_name_Peter Monroe                                   -6.375767e-02
# manager_name_Simon Roup                                     -1.080187e-01
# manager_name_Webster Butler                                 -2.635231e-02
# position_Administrative Assistant                           -4.827370e-02
# position_Area Sales Manager                                  8.390585e-02
# position_CIO                                                -6.666667e-02
# position_Database Administrator                             -1.132277e-01
# position_Director of Operations                             -6.666667e-02
# position_Director of Sales                                   5.000000e-02
# position_IT Director                                        -6.666667e-02
# position_IT Manager - DB                                     7.082882e-02
# position_IT Manager - Infra                                 -6.666667e-02
# position_IT Manager - Support                               -6.666667e-02
# position_IT Support                                          4.187658e-02
# position_Network Engineer                                   -4.504916e-02
# position_President & CEO                                     5.000000e-02
# position_Production Manager                                  6.375767e-02
# position_Production Technician I                             3.854144e-03
# position_Production Technician II                           -9.791225e-03
# position_Sales Manager                                       1.930948e-02
# position_Shared Services Manager                             7.082882e-02
# position_Software Engineer                                  -4.504916e-02
# position_Software Engineering Manager                        5.000000e-02
# position_Sr. Accountant                                     -1.180480e-02
# position_Sr. DBA                                            -1.675063e-02
# position_Sr. Network Engineer                               -4.502252e-02
# performance_score_Exceeds                                   -3.698001e-01
# performance_score_Exceptional                               -2.027212e-01
# performance_score_Fully Meets                                1.000000e+00
# performance_score_N/A- too early to review                  -4.322831e-01
# performance_score_Needs Improvement                         -2.644429e-01
# performance_score_PIP                                       -2.027212e-01
#
#                                             performance_score_N/A- too early to review  \
# zip                                                                          -0.055221
# age                                                                          -0.161248
# pay_rate                                                                     -0.065077
# sex_Male                                                                     -0.094474
# manager_name_Amy Dunn                                                         0.096059
# manager_name_Board of Directors                                              -0.030618
# manager_name_Brandon R. LeBlanc                                               0.076501
# manager_name_Brannon Miller                                                  -0.102525
# manager_name_David Stanley                                                    0.056343
# manager_name_Debra Houlihan                                                  -0.037562
# manager_name_Elijiah Gray                                                     0.011494
# manager_name_Eric Dougall                                                    -0.043446
# manager_name_Janet King                                                      -0.097174
# manager_name_Jennifer Zamora                                                 -0.053390
# manager_name_John Smith                                                      -0.082684
# manager_name_Kelley Spirea                                                   -0.066252
# manager_name_Ketsia Liebig                                                   -0.023091
# manager_name_Kissy Sullivan                                                  -0.066252
# manager_name_Lynn Daneault                                                   -0.029765
# manager_name_Michael Albert                                                   0.128114
# manager_name_Peter Monroe                                                     0.157547
# manager_name_Simon Roup                                                       0.083730
# manager_name_Webster Butler                                                   0.016626
# position_Administrative Assistant                                             0.166154
# position_Area Sales Manager                                                  -0.082110
# position_CIO                                                                 -0.021614
# position_Database Administrator                                               0.069782
# position_Director of Operations                                              -0.021614
# position_Director of Sales                                                   -0.021614
# position_IT Director                                                         -0.021614
# position_IT Manager - DB                                                     -0.030618
# position_IT Manager - Infra                                                  -0.021614
# position_IT Manager - Support                                                -0.021614
# position_IT Support                                                          -0.043446
# position_Network Engineer                                                     0.112502
# position_President & CEO                                                     -0.021614
# position_Production Manager                                                  -0.082684
# position_Production Technician I                                              0.005741
# position_Production Technician II                                             0.025653
# position_Sales Manager                                                       -0.037562
# position_Shared Services Manager                                             -0.030618
# position_Software Engineer                                                   -0.065725
# position_Software Engineering Manager                                        -0.021614
# position_Sr. Accountant                                                      -0.030618
# position_Sr. DBA                                                              0.044914
# position_Sr. Network Engineer                                                 0.109674
# performance_score_Exceeds                                                    -0.119894
# performance_score_Exceptional                                                -0.065725
# performance_score_Fully Meets                                                -0.432283
# performance_score_N/A- too early to review                                    1.000000
# performance_score_Needs Improvement                                          -0.085736
# performance_score_PIP                                                        -0.065725
#
#                                             performance_score_Needs Improvement  \
# zip                                                                   -0.032705
# age                                                                   -0.070494
# pay_rate                                                               0.029922
# sex_Male                                                               0.113490
# manager_name_Amy Dunn                                                 -0.062718
# manager_name_Board of Directors                                       -0.018730
# manager_name_Brandon R. LeBlanc                                       -0.035338
# manager_name_Brannon Miller                                           -0.002787
# manager_name_David Stanley                                            -0.062718
# manager_name_Debra Houlihan                                            0.130720
# manager_name_Elijiah Gray                                             -0.005651
# manager_name_Eric Dougall                                             -0.026578
# manager_name_Janet King                                                0.066119
# manager_name_Jennifer Zamora                                           0.076572
# manager_name_John Smith                                                0.021918
# manager_name_Kelley Spirea                                            -0.064309
# manager_name_Ketsia Liebig                                            -0.002787
# manager_name_Kissy Sullivan                                           -0.005651
# manager_name_Lynn Daneault                                            -0.048656
# manager_name_Michael Albert                                            0.111664
# manager_name_Peter Monroe                                             -0.050581
# manager_name_Simon Roup                                               -0.056031
# manager_name_Webster Butler                                            0.057143
# position_Administrative Assistant                                     -0.022978
# position_Area Sales Manager                                           -0.018461
# position_CIO                                                          -0.013222
# position_Database Administrator                                       -0.048656
# position_Director of Operations                                       -0.013222
# position_Director of Sales                                            -0.013222
# position_IT Director                                                  -0.013222
# position_IT Manager - DB                                              -0.018730
# position_IT Manager - Infra                                            0.252102
# position_IT Manager - Support                                         -0.013222
# position_IT Support                                                   -0.026578
# position_Network Engineer                                             -0.040206
# position_President & CEO                                              -0.013222
# position_Production Manager                                            0.094417
# position_Production Technician I                                       0.037507
# position_Production Technician II                                     -0.071721
# position_Sales Manager                                                 0.130720
# position_Shared Services Manager                                      -0.018730
# position_Software Engineer                                             0.049439
# position_Software Engineering Manager                                 -0.013222
# position_Sr. Accountant                                               -0.018730
# position_Sr. DBA                                                      -0.026578
# position_Sr. Network Engineer                                         -0.029765
# performance_score_Exceeds                                             -0.073343
# performance_score_Exceptional                                         -0.040206
# performance_score_Fully Meets                                         -0.264443
# performance_score_N/A- too early to review                            -0.085736
# performance_score_Needs Improvement                                    1.000000
# performance_score_PIP                                                 -0.040206
#
#                                             performance_score_PIP
# zip                                                      0.162007
# age                                                      0.021994
# pay_rate                                                -0.014045
# sex_Male                                                 0.008005
# manager_name_Amy Dunn                                    0.028492
# manager_name_Board of Directors                         -0.014359
# manager_name_Brandon R. LeBlanc                         -0.027090
# manager_name_Brannon Miller                              0.258205
# manager_name_David Stanley                              -0.048080
# manager_name_Debra Houlihan                             -0.017615
# manager_name_Elijiah Gray                               -0.049299
# manager_name_Eric Dougall                               -0.020374
# manager_name_Janet King                                 -0.045570
# manager_name_Jennifer Zamora                            -0.025038
# manager_name_John Smith                                  0.053854
# manager_name_Kelley Spirea                              -0.049299
# manager_name_Ketsia Liebig                              -0.048080
# manager_name_Kissy Sullivan                              0.025645
# manager_name_Lynn Daneault                               0.058659
# manager_name_Michael Albert                              0.025645
# manager_name_Peter Monroe                               -0.038775
# manager_name_Simon Roup                                 -0.042953
# manager_name_Webster Butler                             -0.048080
# position_Administrative Assistant                       -0.017615
# position_Area Sales Manager                              0.081419
# position_CIO                                            -0.010136
# position_Database Administrator                         -0.037300
# position_Director of Operations                         -0.010136
# position_Director of Sales                              -0.010136
# position_IT Director                                    -0.010136
# position_IT Manager - DB                                -0.014359
# position_IT Manager - Infra                             -0.010136
# position_IT Manager - Support                           -0.010136
# position_IT Support                                     -0.020374
# position_Network Engineer                               -0.030822
# position_President & CEO                                -0.010136
# position_Production Manager                             -0.038775
# position_Production Technician I                        -0.002604
# position_Production Technician II                        0.064509
# position_Sales Manager                                  -0.017615
# position_Shared Services Manager                        -0.014359
# position_Software Engineer                              -0.030822
# position_Software Engineering Manager                   -0.010136
# position_Sr. Accountant                                 -0.014359
# position_Sr. DBA                                        -0.020374
# position_Sr. Network Engineer                           -0.022818
# performance_score_Exceeds                               -0.056225
# performance_score_Exceptional                           -0.030822
# performance_score_Fully Meets                           -0.202721
# performance_score_N/A- too early to review              -0.065725
# performance_score_Needs Improvement                     -0.040206
# performance_score_PIP                                    1.000000
#
# [52 rows x 52 columns]

# %%
#abs(hr_data.corr())>0.75

# %%
sns.heatmap(hr_data.corr(), center=0)

# %%
hr_data.columns
# Out:
# Index(['name', 'state', 'zip', 'DOB', 'age', 'marital_desc', 'citizen_desc',
#        'hispanic', 'race', 'date_of_hire', 'date_of_term', 'reason_for_term',
#        'emp_status', 'department', 'pay_rate', 'employee_source', 'sex_Male',
#        'manager_name_Amy Dunn', 'manager_name_Board of Directors',
#        'manager_name_Brandon R. LeBlanc', 'manager_name_Brannon Miller',
#        'manager_name_David Stanley', 'manager_name_Debra Houlihan',
#        'manager_name_Elijiah Gray', 'manager_name_Eric Dougall',
#        'manager_name_Janet King', 'manager_name_Jennifer Zamora',
#        'manager_name_John Smith', 'manager_name_Kelley Spirea',
#        'manager_name_Ketsia Liebig', 'manager_name_Kissy Sullivan',
#        'manager_name_Lynn Daneault', 'manager_name_Michael Albert',
#        'manager_name_Peter Monroe', 'manager_name_Simon Roup',
#        'manager_name_Webster Butler', 'position_Administrative Assistant',
#        'position_Area Sales Manager', 'position_CIO',
#        'position_Database Administrator', 'position_Director of Operations',
#        'position_Director of Sales', 'position_IT Director',
#        'position_IT Manager - DB', 'position_IT Manager - Infra',
#        'position_IT Manager - Support', 'position_IT Support',
#        'position_Network Engineer', 'position_President & CEO',
#        'position_Production Manager', 'position_Production Technician I',
#        'position_Production Technician II', 'position_Sales Manager',
#        'position_Shared Services Manager', 'position_Software Engineer',
#        'position_Software Engineering Manager', 'position_Sr. Accountant',
#        'position_Sr. DBA', 'position_Sr. Network Engineer',
#        'performance_score_Exceeds', 'performance_score_Exceptional',
#        'performance_score_Fully Meets',
#        'performance_score_N/A- too early to review',
#        'performance_score_Needs Improvement', 'performance_score_PIP'],
#       dtype='object')

# %%
feats = ['manager_name_Amy Dunn','performance_score_Exceeds', 'performance_score_Exceptional','performance_score_Fully Meets','performance_score_N/A- too early to review','performance_score_Needs Improvement', 'performance_score_PIP']
corr = hr_data[feats].corr()
descr = hr_data[feats].describe()
descr
# Out:
#        manager_name_Amy Dunn  performance_score_Exceeds  \
# count             301.000000                 301.000000
# mean                0.069767                   0.093023
# std                 0.255179                   0.290949
# min                 0.000000                   0.000000
# 25%                 0.000000                   0.000000
# 50%                 0.000000                   0.000000
# 75%                 0.000000                   0.000000
# max                 1.000000                   1.000000
#
#        performance_score_Exceptional  performance_score_Fully Meets  \
# count                     301.000000                     301.000000
# mean                        0.029900                       0.571429
# std                         0.170596                       0.495696
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       1.000000
# 75%                         0.000000                       1.000000
# max                         1.000000                       1.000000
#
#        performance_score_N/A- too early to review  \
# count                                  301.000000
# mean                                     0.122924
# std                                      0.328896
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#        performance_score_Needs Improvement  performance_score_PIP
# count                           301.000000             301.000000
# mean                              0.049834               0.029900
# std                               0.217964               0.170596
# min                               0.000000               0.000000
# 25%                               0.000000               0.000000
# 50%                               0.000000               0.000000
# 75%                               0.000000               0.000000
# max                               1.000000               1.000000

# %%
fig, ax = plt.subplots(figsize=(10,5))   
ax = sns.heatmap(corr, center=5, annot=True, linewidths=.5, ax=ax)
